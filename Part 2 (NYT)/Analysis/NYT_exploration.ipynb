# %% [markdown]
# # NYT Predictions Exploration

# %% [markdown]
# In this notebook, we create a bar graph depicting the average predicted normative rating of each category. We also retrieve captions for our other plots here.
#
# Below is a code chunk that allows you to pop-out all graphs and visuals produced in this notebook. It will making viewing some graphs in this notebook significantly easier, as otherwise, the text for these graphs may not fit nicely.
#
# Below that is another code chunk that reverts this.

# %%
# Run to make the plots pop out of the .ipynb file
# %matplotlib qt

# %%
# Run to make the plots stay in the .ipynb file (if using vscode)
# %matplotlib inline

# %% [markdown]
# ## Imports and Setting-up

# %%
# Imports
import json
import matplotlib.pyplot as plt
import numpy as np
import pickle
import math
import ruptures as rp
import scipy.stats as sp

# %%
# Load necessary data
with open(".\JointPredictions.pickle", 'rb') as handle:
    predictions = pickle.load(handle)
with open(".\imagedetails.pickle", 'rb') as handle:
    details = pickle.load(handle) # YYYY-MM, ID, Link
with open(".\\token_mask.pickle", 'rb') as handle:
    mask = pickle.load(handle) # YYYY-MM, ID, Link
details = details[mask]

unique_mask = np.unique(details[:,2:], return_index=True, axis=0)[1]
details = details[unique_mask]
predictions = predictions[unique_mask]

# %%
JSONFOLDER = ".\Data\captioning_dataset.json"
with open(JSONFOLDER) as f:
    caption_data = json.load(f)
def retrieve_caption(article_id, image_id):
    return caption_data[article_id]['images'][image_id]

# %% [markdown]
# ## Ebola Plot (and Changepoint Detection)

# %%
with open(".\JointPredictions.pickle", 'rb') as handle:
    predictions_j = pickle.load(handle)
with open(".\imagedetails.pickle", 'rb') as handle:
    details = pickle.load(handle)
with open(".\\token_mask.pickle", 'rb') as handle:
    token_mask = pickle.load(handle)
details = details[token_mask]
# Two links aren't associated with dates. Get rid of them.
# The links are:
# https://www.nytimes.com/interactive/2015/health/stillbirth-reader-stories.html
# https://www.nytimes.com/interactive/2015/world/nobel-peace-prize-timeline.html
mask = (details[:,0]!='2015-00')
details = details[mask]
predictions_j = predictions_j[mask]

months = []
all_months = np.unique(details[:,0])
for y in ["2013","2014", "2015"]:
    mask = np.flatnonzero(np.core.defchararray.find(all_months, y)!=-1)
    months.extend(all_months[mask])
months = np.array(months)

unique_mask = np.unique(details[:,2:], return_index=True, axis=0)[1]
details = details[unique_mask]
predictions_j = predictions_j[unique_mask]

# %%
def get_category_subset(predictions, details, category):
    #Returns the subset of predictions and details that match the category
    # Code below taken from:
    # https://stackoverflow.com/questions/38974168/finding-entries-containing-a-substring-in-a-numpy-array
    mask = np.flatnonzero(np.core.defchararray.find(details[:,3], category)!=-1)
    category_details = details[mask]
    category_predictions = predictions[mask]
    return category_predictions, category_details

def get_timecourse(predictions, details, months=months):
    means = []
    error = []
    for m in months:
        month_mask = (details[:,0]==m)
        means.append(np.mean(predictions[month_mask]))
        error.append(sp.sem(predictions[month_mask]))
    return np.array(means), np.array(error)

# %%
health_auth_p, health_auth_d= get_category_subset(predictions_j[:,3], details, "/health/")
health_auth_m, health_auth_e=get_timecourse(health_auth_p,health_auth_d)
sports_auth_p, sports_auth_d= get_category_subset(predictions_j[:,3], details, "/sports/")
sports_auth_m, sports_auth_e=get_timecourse(sports_auth_p,sports_auth_d)

# %%
detectors = rp.Pelt(model="rbf")
detectors.fit(np.array(health_auth_m))

changepoints = detectors.predict(pen=2)
if 0 in changepoints:
    changepoints.remove(0)
if len(months) in changepoints:
    changepoints.remove(len(months))

# %%
# Set up Title and axes
plt.title('Impact of Ebola Outbreak on NYT News')
plt.ylabel("Mean Relevance to Authority")
plt.xlabel("Time (in months)")
xticks = range(0, len(months), 1)
plt.xticks(xticks, months[xticks], rotation ='vertical', fontsize=8)
# Set up the background colours
num_years = math.ceil(len(months)/12)
for i in range(0, num_years, 2):
    plt.axvspan(12*i-0.5, 12*(i+1)-0.5, color='xkcd:sky blue', alpha=0.2)
# Set up the background text
for i in range(0, num_years, 1):
    plt.text(12*i+5, 2.8, months[12*i][:4], color="tab:gray", size="large")
plt.axvline(x = 12+8-1, color = 'green', alpha=0.5)

# Plot the points
plt.plot(range(len(months)), health_auth_m, color="tab:purple", label="health")
plt.fill_between(range(len(months)), np.array(health_auth_m)-np.array(health_auth_e), 
                 np.array(health_auth_m)+np.array(health_auth_e), color="tab:purple", alpha=0.25)
plt.plot(range(len(months)), sports_auth_m, color="tab:blue", label="sports")
plt.fill_between(range(len(months)), np.array(sports_auth_m)-np.array(sports_auth_e), 
                 np.array(sports_auth_m)+np.array(sports_auth_e), color="tab:blue", alpha=0.25)
# Plot the changepoint detection points
for cp in changepoints:
    plt.plot(cp, health_auth_m[cp], 'ro') 

plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Bar Graph of each category

# %%
plt.rcParams.update({'font.size': 12})

mask_1 = np.flatnonzero(np.core.defchararray.find(details[:,3], "/sports/")!=-1)
mask_2 = np.flatnonzero(np.core.defchararray.find(details[:,3], "/business/")!=-1)
mask_3 = np.flatnonzero(np.core.defchararray.find(details[:,3], "/technology/")!=-1)
mask_4 = np.flatnonzero(np.core.defchararray.find(details[:,3], "/science/")!=-1)
mask_5 = np.flatnonzero(np.core.defchararray.find(details[:,3], "/health/")!=-1)

cut = [3,4,5,6,7]

var_names = np.array(["Valence", "Arousal", 
            "Moral", "Authority",
            "Fairness", "Care",
            "Ingroup", "Purity"])[cut]
  
X_axis = np.arange(len(var_names)) 
  
w=0.15

vals = predictions[mask_1][:,cut]
plt.bar(X_axis - 2*w, np.average(vals, axis=0), w, label = 'Sports (n={})'.format(len(vals)))
plt.errorbar(X_axis - 2*w, np.average(vals, axis=0), sp.sem(vals, axis=0), fmt="none", color="black")
vals = predictions[mask_2][:,cut]
plt.bar(X_axis - w, np.average(vals, axis=0), w, label = 'Business (n={})'.format(len(vals)))
plt.errorbar(X_axis - w, np.average(vals, axis=0), sp.sem(vals, axis=0), fmt="none", color="black")
vals = predictions[mask_3][:,cut]
plt.bar(X_axis, np.average(vals, axis=0), w, label = 'Technology (n={})'.format(len(vals))) 
plt.errorbar(X_axis, np.average(vals, axis=0), sp.sem(vals, axis=0), fmt="none", color="black")
vals = predictions[mask_4][:,cut]
plt.bar(X_axis + w, np.average(vals, axis=0), w, label = 'Science (n={})'.format(len(vals))) 
plt.errorbar(X_axis + w, np.average(vals, axis=0), sp.sem(vals, axis=0), fmt="none", color="black")
vals = predictions[mask_5][:,cut]
plt.bar(X_axis + 2*w, np.average(vals, axis=0), w, label = 'Health (n={})'.format(len(vals))) 
plt.errorbar(X_axis + 2*w, np.average(vals, axis=0), sp.sem(vals, axis=0), fmt="none", color="black")


plt.xticks(X_axis, var_names) 
plt.xlabel("Moral Foundation") 
plt.ylabel("Mean Inferred Relevance of Images to Moral Foundation") 
plt.ylim(1, 5)
plt.title("Average Relevance of NYT Images to the different Moral Foundations") 
plt.legend() 
plt.show()

#ax = plt.subplot(111)
#ax.bar(x-0.2, y, width=0.2, color='b', align='center')
#ax.bar(x, z, width=0.2, color='g', align='center')
#ax.bar(x+0.2, k, width=0.2, color='r', align='center')
#ax.xaxis_date()

cats=["spo","bus","tec","sci","hea"]
masks=[mask_1,mask_2,mask_3,mask_4,mask_5]
for i in range(len(masks)):
    print(cats[i])
    vals = predictions[masks[i]][:,2]
    print(np.mean(vals), sp.sem(vals, axis=0))

# %%
# Health--Moral
category_mask = np.flatnonzero(np.core.defchararray.find(details[:,3], "/health/")!=-1)
ordered = np.argsort(predictions[category_mask][:,2])
for i in range(-1, -21, -1):
    article_id = details[category_mask][:,1][ordered[i]]
    image_id = details[category_mask][:,2][ordered[i]]
    print(details[category_mask][:,3][ordered[i]])
    print(retrieve_caption(article_id, image_id))
# Out:
# https://www.nytimes.com/2017/03/27/health/medicaid-obamacare.html
# Tracie Scott with her newborn daughter, Izabella, at a hospital in Ohio. Ms. Scott, who has multiple sclerosis, is covered by Medicaid, along with her four children.
# https://www.nytimes.com/2012/09/20/health/transplant-experts-blame-allocation-system-for-discarding-kidneys.html
#
# A moment of silence for a donor at Fairview Southdale Hospital in Edina, Minn.
#
#
# https://www.nytimes.com/2015/02/26/health/researchers-call-for-more-study-of-anesthesia-risks-to-young-children.html
# Dr. Randall Flick, pediatric anesthesiologist at the Mayo Clinic Children's Center, gives anesthesia to an infant for a minor surgical procedure.
# https://www.nytimes.com/2018/01/15/health/baby-spina-bifida-surgery.html
# After undergoing experimental surgery for spina bifida in September while still in the womb, a baby boy was born in Texas Children’s Hospital in Houston on Friday.
# https://www.nytimes.com/2012/12/23/health/new-drugs-aim-to-make-cells-destroy-cancer.html
#
# Joe Bellino, shown with his daughter, had a rare kind of cancer that could respond well.
#
# https://www.nytimes.com/2017/11/26/health/health-care-hospitals-insurers.html
# Aetna started offering joint plans with Inova in 2013, and the partnership now covers more than 193,000 people in Northern Virginia.
# https://www.nytimes.com/2012/06/22/health/billions-of-dollars-in-play-over-health-care-law.html
#
# Alda Vintimilla and her daughter receiving care at the Hudson River Community Health Care Center in Peekskill, N.Y.
#
#
# https://www.nytimes.com/2018/01/10/health/rsv-symptoms-prevention.html
# Kate Lacovara-Green, 15 months, with her father Sam Green on Dec. 7 in the Pediatric Intensive Care Unit at the New York Presbyterian Hospital-Cornell Medical Center on day three of her seven-day hospital stay.
# https://www.nytimes.com/2015/12/15/health/canine-flu-has-dog-owners-wondering-if-fido-needs-a-vaccine.html
# Dr. Jerry Klein, right, and Molly Duignan, a veterinary technician, examining Delila, a 13-year-old beagle in Chicago. Many dogs in Chicago last spring were sickened during an outbreak of canine influenza that has turned up in 24 other states.
# https://www.nytimes.com/2016/04/21/health/how-medicare-penalizes-hospitals-for-being-too-careful.html
# Andrea Stone, left, and Kaleigh Nolan at Northwestern Memorial Hospital. “Hand hygiene, as easy as it sounds, that takes a lot,” Ms. Stone said.
# https://www.nytimes.com/2013/04/15/health/live-music-soothes-premature-babies-a-new-study-finds.html
#
# Angela Ferraiuolo-Thompson, left, used a Beatles song to calm Hudson, born 13 weeks preterm, at Beth Israel Medical Center.
#
#
# https://www.nytimes.com/2010/12/28/health/28dating.html
#
# Sherry Nevius uses an online dating site specifically for those with disabilities.
#
#
# https://www.nytimes.com/2010/09/02/health/research/02alzheimer.html
#
# Paul Greengard with his dog Alpha. Dr. Greengard made a discovery that could help slow or stop the effects of Alzheimer's.
#
#
# https://www.nytimes.com/2010/04/13/health/13klas.html
#
# Dr. Eve Kimball, left, was the first female intern in the Army. Her daughter, Maj. Catherine Kimball-Eayrs, at Walter Reed Army Medical Center.
#
#
# https://www.nytimes.com/2013/09/06/health/fertility-rate-stabilizes-as-the-economy-grows.html
#
# Lincoln Marie McGeorge, 1 day old, with her parents, Morgan McGeorge and Bryon Waltz, in Casper, Wyo., last month.
#
#
# https://www.nytimes.com/2017/07/06/health/uk-infant-charlie-gard-ny-hospital.html
# Charlie Gard, at Great Ormond Street Hospital in London, has a disease so rare it is believed to affect just over a dozen children worldwide.
# https://www.nytimes.com/2016/12/29/health/did-debbie-reynolds-die-of-a-broken-heart.html
# Carrie Fisher with her mother, Debbie Reynolds, in 2010. By all accounts the two were very close in recent years.
# https://www.nytimes.com/2013/03/31/health/state-senate-bill-would-revise-end-of-life-procedure.html
#
# Dr. Leigh Fredholm, left, medical director of palliative care, and Liz Powell, a chaplain, with a patient at University Medical Center Brackenridge.
#
#
# https://www.nytimes.com/2016/07/12/health/silver-diamine-fluoride-dentist-cavities.html
# After Dr. MacLean treated Knox, she gave him a sticker.
# https://www.nytimes.com/2010/06/29/health/29geri.html
#
# SPECIALIZATION Marilyn Lopez, center, and Anessa Uretsky, right, N.Y.U. nurses in geriatrics, with a patient, Geraldine Goldsmith.

# %%
# Sports--Fairness
category_mask = np.flatnonzero(np.core.defchararray.find(details[:,3], "/sports/")!=-1)
ordered = np.argsort(predictions[category_mask][:,4])
for i in range(-1, -21, -1):
    article_id = details[category_mask][:,1][ordered[i]]
    image_id = details[category_mask][:,2][ordered[i]]
    print(details[category_mask][:,3][ordered[i]])
    print(retrieve_caption(article_id, image_id))
# Out:
# https://www.nytimes.com/2013/11/27/sports/hockey/nfl-concussion-case-offers-clues-for-hockey-lawsuit.html
#
# Curt Bennett (19) of St. Louis in a brawl in Boston in 1972. Bennett is among the former N.H.L. players who have sued the league.
#
#
# https://www.nytimes.com/2010/06/20/sports/soccer/20usteam.html
#
# United States players argued with the referee Koman Coulibaly after he disallowed a goal Friday.
#
#
# https://www.nytimes.com/2011/10/11/sports/john-carlos-of-68-olympics-protest-maintains-his-passion.html
#
# John Carlos, right, and Tommie Smith protested treatment of blacks in America after the 200-meter final at the 1968 Mexico City Olympics.
#
#
# https://www.nytimes.com/2015/12/01/sports/international/coin-toss-is-secure-in-sports-lore-if-not-in-cricket.html
# A coin toss before an N.F.L. game between the Saints and the Giants in November.
# https://www.nytimes.com/2015/05/01/sports/a-ringside-seat.html
#
# Boxer Joe Frazier being directed to the ropes by referee Arthur Marcante after knocking down Muhammad Ali during the 15th round of the title bout at Madison Square Garden in New York on March 8, 1971.
#
#
# https://www.nytimes.com/2012/09/23/sports/football/with-nfl-replacement-officials-on-field-pace-of-games-sputters.html
#
# The referee Wayne Elliott reviewing a play. There is a hesitancy from many replacements when it comes to handling TV duties.
#
#
# https://www.nytimes.com/2016/07/18/sports/olympics/john-carlos-tommie-smith-committee-apology.html
# Tommie Smith, center, and John Carlos, right, were sent home for their actions on the medal stand in the 1968 Summer Olympics.
# https://www.nytimes.com/2013/07/10/sports/baseball/30-years-later-brett-is-still-dealing-with-pine-tar.html
#
# George Brett, center, was restrained by Joe Brinkman after he was ruled out by Tim McClelland, right, on July 24, 1983.
#
# https://www.nytimes.com/2012/09/26/sports/football/absurd-ending-fuels-disgust-with-replacement-refs.html
#
# The referees initially gave different signals on the disputed game-deciding play.
#
#
# https://www.nytimes.com/2014/03/12/sports/olympics/student-russia-beats-teacher-us-in-sledge-hockey.html
# Rico Roman of the United States, left, and Ilia Volkov of Russia clashed on Tuesday.
# https://www.nytimes.com/2012/03/18/sports/ncaabasketball/too-good-to-fail-syracuse-moves-on-to-round-of-16.html
#
# Scoop Jardine of Syracuse went over the scorer’s table in pursuit of the ball during the Orange’s third-round victory.
#
#
# https://www.nytimes.com/2013/04/04/sports/baseball/ebbets-field-is-gone-but-memories-of-brooklyn-dodgers-endure.html
#
# Jackie Robinson crossing the plate at Ebbets Field in 1952.
#
#
# https://www.nytimes.com/2016/09/08/sports/football/colin-kaepernick-anthem-protest-nfl-roger-goodell.html
# The 49ers’ Colin Kaepernick kneeling during the national anthem in a protest of racial inequality.
# https://www.nytimes.com/2012/08/10/sports/olympics/katie-taylor-pride-of-ireland-wins-boxing-gold-medal.html
#
# Taylor, in red, fights against Russia’s Sofya Ochigava.
#
#
# https://www.nytimes.com/2018/01/01/sports/nfl-national-anthem-protests.html
# Several members of the San Francisco 49ers kneel during the national anthem before a game Sunday against Los Angeles Rams at Los Angeles Memorial Coliseum. Sideline protests by N.F.L. players, inspired by a gesture by former 49ers quarterback Colin Kaepernick, continue but on a smaller scale as the season ends.
# https://www.nytimes.com/2017/09/23/sports/trump-nfl-colin-kaepernick-.html
# Colin Kaepernick (7) kneeling with his teammate Eric Reid during the national anthem before a San Francisco 49ers game last season.
# https://www.nytimes.com/2015/07/23/sports/soccer/mexico-reaches-gold-cup-final-after-heated-win-over-panama.html
# Players from Panama, in red, rushed toward the referee Mark Geiger, left, when the match ended.
# https://www.nytimes.com/2017/09/27/sports/nfl-protests-australia-peter-norman.html
# Peter Norman, left, was ostracized in Australia after the protest by the Americans Tommie Smith, center, and John Carlos in 1968.
# https://www.nytimes.com/2018/05/07/sports/football/eric-reid-nfl-national-anthem.html
# Eric Reid, right, kneeling with his former 49ers teammate Colin Kaepernick during the national anthem in 2017.
# https://www.nytimes.com/2013/03/24/sports/ncaabasketball/arizona-tops-harvard.html
#
# Mark Lyons of Arizona, in white, fighting for a loose ball with Laurent Rivard and Siyani Chambers of Harvard.

# %%
# Sports--Ingroup
category_mask = np.flatnonzero(np.core.defchararray.find(details[:,3], "/sports/")!=-1)
ordered = np.argsort(predictions[category_mask][:,6])
#details[mask][ordered]
for i in range(-1, -21, -1):
    article_id = details[category_mask][:,1][ordered[i]]
    image_id = details[category_mask][:,2][ordered[i]]
    print(details[category_mask][:,3][ordered[i]])
    print(retrieve_caption(article_id, image_id))
# Out:
# https://www.nytimes.com/2013/04/19/sports/near-boston-marathons-finish-line-no-talk-of-defeat.html
#
# Tamera Clifton, who finished the race before the bombings, hugged her daughter Aislin near the Boylston Street memorial.
#
#
# https://www.nytimes.com/2018/05/07/sports/football/eric-reid-nfl-national-anthem.html
# Eric Reid, right, kneeling with his former 49ers teammate Colin Kaepernick during the national anthem in 2017.
# https://www.nytimes.com/2015/09/27/sports/letters-to-the-editor.html
# A young fan placed a baseball at the foot of a Yogi Berra statue at Berra’s museum in Little Falls, N.J., on Wednesday.
# https://www.nytimes.com/2011/09/23/sports/golf/2011-solheim-cup-otoole-and-inkster-share-more-than-roles-on-us-team.html
#
# The U.S. captain Rosie Jones, left, at the Solheim ceremony Thursday.
#
#
# https://www.nytimes.com/2017/05/14/sports/baseball/derek-jeter-new-york-yankees-monument-park.html
# On Sept. 11, 2016, pitcher Dellin Betances and Manager Joe Girardi carried a wreath to the September 11th memorial in Monument Park.
# https://www.nytimes.com/2015/10/02/sports/basketball/former-head-of-joint-chiefs-will-advise-nba-and-adam-silver.html
# President Obama with Gen. Martin E. Dempsey at his retirement ceremony last Friday.
# https://www.nytimes.com/2013/11/04/sports/at-the-marathon-security-prevails.html
#
# Officer Kevin Belavsky and his bomb-sniffing dog, Ellis, at the New York City Marathon, the first since the Boston bombings.
#
#
# https://www.nytimes.com/2013/08/06/sports/football/at-28-rookie-refuses-to-focus-on-time-lost.html
#
# Brian Banks with his mother, Leomia Myers, after his conviction was overturned.
#
#
# https://www.nytimes.com/2014/04/22/sports/baseball/baseball-roundup.html
# Marc Fucarile, right, a survivor of the Boston Marathon bombing, with the former Red Sox player Kevin Millar after Fucarile threw the ceremonial first pitch.
# https://www.nytimes.com/2014/07/13/sports/worldcup/world-cup-2014-before-manuel-neuer-was-germanys-keeper-there-was-robert-enke.html
# Enke in 2006 with his daughter Lara, who died from a rare heart condition. He is buried next to her.
# https://www.nytimes.com/2017/09/23/sports/trump-nfl-colin-kaepernick-.html
# Colin Kaepernick (7) kneeling with his teammate Eric Reid during the national anthem before a San Francisco 49ers game last season.
# https://www.nytimes.com/2010/07/16/sports/baseball/16vecsey.html
#
# Bob Sheppard’s funeral on Thursday.
#
#
# https://www.nytimes.com/2018/02/23/sports/olympics/united-states-womens-hockey.html
# The American defender Megan Keller (5) hugging her teammate Kendall Coyne after winning the gold in women’s hockey.
# https://www.nytimes.com/2011/09/10/sports/ncaafootball/army-embraces-football-while-preparing-for-reality.html
#
# First Lt. Tyson Quink, a former player, and his wife, First Lt. Tera Quink. He lost his legs this spring in Afghanistan.
#
#
# https://www.nytimes.com/2016/06/04/sports/soccer/judge-rules-us-womens-soccer-team-cant-strike-before-olympics.html
# The United States women’s national team before a friendly against Japan on June 2.
# https://www.nytimes.com/2010/11/21/sports/ncaafootball/21army.html
#
# Army cadets before the first football game at the new Yankee Stadium. Army and Notre Dame played 22 times at the old Stadium.
#
#
# https://www.nytimes.com/2010/02/24/sports/olympics/24nordic.html
#
# Todd Lodwick, a five-time Olympian, celebrating his medal in the Nordic combined relay with his child.
#
#
# https://www.nytimes.com/2017/10/10/sports/football/nfl-goodell-anthem-kneeling.html
# Members of the San Francisco 49ers knelt during the national anthem before the game against the Colts on Sunday.
# https://www.nytimes.com/2016/09/27/sports/basketball/nba-national-anthem-protests-carmelo-anthony-jeremy-lin.html
# Eric Reid, left, and Colin Kaepernick kneeling during the national anthem. N.B.A. players are debating whether to join a protest.
# https://www.nytimes.com/2012/12/04/sports/football/there-is-no-playbook-for-what-the-chiefs-face.html
#
# Players praying after the Chiefs’ victory over the Panthers on Sunday.

# %%
# Health--Purity
category_mask = np.flatnonzero(np.core.defchararray.find(details[:,3], "/health/")!=-1)
ordered = np.argsort(predictions[category_mask][:,7])
#details[mask][ordered]
for i in range(-1, -21, -1):
    article_id = details[category_mask][:,1][ordered[i]]
    image_id = details[category_mask][:,2][ordered[i]]
    print(details[category_mask][:,3][ordered[i]])
    print(retrieve_caption(article_id, image_id))
# Out:
# https://www.nytimes.com/2013/10/22/health/in-syria-doctors-risk-life-and-juggle-ethics.html
#
# A Syrian man mourned over a victim of a poison gas attack in Douma, a city on the outskirts of Damascus, in August.
#
#
# https://www.nytimes.com/2017/06/19/health/guns-children-cdc-us-firearms.html
# Parents of children killed by guns held a protest in Atlanta near the National Rifle Association’s annual convention in April.
# https://www.nytimes.com/2018/06/04/health/nipah-virus-india-vaccine-epidemic.html
# Burying a victim of the Nipah virus in Kozhikode, southern India. There is no vaccine and no cure for the disease.
# https://www.nytimes.com/2012/05/08/health/research/lenins-death-remains-a-mystery-for-doctors.html
#
# The Soviet leader Vladimir Ilyich Lenin on his death bed, in an undated photo.
#
#
# https://www.nytimes.com/2013/07/22/health/pakistan-fights-for-ground-in-war-on-polio.html
#
# A child received a polio vaccine in a volatile neighborhood on the outskirts of Karachi, Pakistan.
#
#
# https://www.nytimes.com/2018/03/05/health/mental-illness-asylums.html
# Students of Marjory Stoneman Douglas High School during a candlelight vigil for the victims of the mass shooting in Parkland, Fla., last month.
# https://www.nytimes.com/2015/02/13/health/ebola-victims-still-infectious-a-week-after-death-scientists-find.html
# A burial team work to bury the body of a man who died from Ebola in the Kissi community of Freetown, Sierra Leone.
# https://www.nytimes.com/2015/03/27/health/ebola-virus-in-latest-outbreak-does-not-show-unusual-mutations-study-finds.html
# A burial team in Bong County, Liberia, in October. Ebola’s mutation rate does not appear to be exceptional.
# https://www.nytimes.com/2011/05/31/health/31aids.html
#
# ADVOCACY A protest at New York's City Hall in 1985. In Council hearings on AIDS-related bills, gay residents said they had become victims of discrimination and hysteria.
#
#
# https://www.nytimes.com/2016/09/18/health/a-mosquito-killer-unwelcome-to-many.html
# A protest against the spraying of naled in San Juan, P.R., in July.
# https://www.nytimes.com/2012/11/26/health/after-dozens-of-deaths-inquiry-into-bed-rails.html
#
# Gloria Black, visiting her mother’s grave in Portland, Ore. She has documented hundreds of deaths associated with bed rails and said families should be informed of their possible risks.
#
#
# https://www.nytimes.com/2017/10/30/health/men-rape-sexual-assault.html
# A dissertation called “The Undetected Rapist” included articles with these headlines. The author suggested that they contribute to misconceptions about rapists, most of whom do not appear in news stories or in court.
# https://www.nytimes.com/2016/06/11/health/gang-stalking-targeted-individuals.html
# Officers standing over the body of Myron May on Nov. 20, 2014, after the shooting at Florida State University.
# https://www.nytimes.com/2018/04/24/health/george-barbara-bush-grief-health.html
# George H.W. Bush with his daughter Dorothy Bush Koch, at a visitation for his wife, Barbara Bush, on Friday in Houston.
# https://www.nytimes.com/2013/07/23/health/report-finds-gradual-fall-in-female-genital-cutting-in-africa.html
#
# A Kenyan girl praying at a safe house in 2006. A United Nations report found that among the 29 nations where the practice is concentrated, the steepest declines have been in Kenya.
#
#
# https://www.nytimes.com/2016/02/02/health/dreams-dying-deathbed-interpretation-delirium.html
# Dr. Kerr holds the hand of a patient, Rebecca Nowak. He says that sometimes when dying people are sedated, “we are sterilizing them from their own dying process.”
# https://www.nytimes.com/2017/10/07/health/africa-cancer-drugs.html
# Paul Mugumya, 7, lying in the Kawempe Home Care facility for children in Kampala, Uganda, had three hernia operations before surgeons realized he had a blistering football-shaped tumor. Cancers — many of them treatable — kill about 450,000 Africans a year.
# https://www.nytimes.com/2016/12/19/health/donald-trump-foreign-aid-global-health.html
# A mother and a child in 2014 in an Ebola isolation ward in Liberia. When asked about foreign aid during the campaign, President-elect Donald J. Trump said tax dollars should go to rebuilding the United States.
# https://www.nytimes.com/2015/10/12/health/the-chains-of-mental-illness-in-west-africa.html
# Kodjo Didier Akarabi, 47, had been left at a prayer camp in Togo for a year by his brothers. “I stay here now because I see things,” he said. Read more about these photos in an interview with Joao Silva.
# https://www.nytimes.com/2011/09/27/health/27docs.html
#
# LESSONS Nigerians in 1969. Smallpox is gone, but measles is still lethal.

# %%
# Health -- Harm
category_mask = np.flatnonzero(np.core.defchararray.find(details[:,3], "/health/")!=-1)
ordered = np.argsort(predictions[category_mask][:,5])
#details[mask][ordered]
for i in range(-1, -21, -1):
    article_id = details[category_mask][:,1][ordered[i]]
    image_id = details[category_mask][:,2][ordered[i]]
    print(details[category_mask][:,3][ordered[i]])
    print(retrieve_caption(article_id, image_id))
# Out:
# https://www.nytimes.com/2017/05/01/health/zika-twins-transmission-theories.html
#
# Ms. Ribeiro giving João Lucas a massage. The boy sometimes became so agitated, he would scratch himself in the face.
#
#
# https://www.nytimes.com/2015/05/08/health/weeks-after-his-recovery-ebola-lurked-in-a-doctors-eye.html
# Dr. Crozier with children at an Ebola treatment unit in Sierra Leone in September 2014.
# https://www.nytimes.com/2016/11/28/health/obamacare-gunshots-medicaid.html
# Mr. Berry with his son, who’s learning to box. Mr. Berry still needs a cane, but has been getting around better with more treatment.
# https://www.nytimes.com/2015/09/29/health/children-with-hiv-more-likely-to-die-of-malaria.html
# A mother and her child who has cerebral malaria and is in a coma at Queen Elizabeth Central Hospital in Malawi.
# https://www.nytimes.com/2014/07/03/health/Vaccine-Costs-Soaring-Paying-Till-It-Hurts.html
#
# PAINFUL MEDICINE Rachel Chavez, left, and Beth Barnhart administer vaccines to Caius Sims as his mother, Cedra Sims, helps hold him at Dr. Lindsay Irvin’s office.
#
#
# https://www.nytimes.com/2013/10/22/health/in-syria-doctors-risk-life-and-juggle-ethics.html
#
# A Syrian man mourned over a victim of a poison gas attack in Douma, a city on the outskirts of Damascus, in August.
#
#
# https://www.nytimes.com/2016/09/01/health/study-finds-increase-in-temporary-paralysis-accompanied-zika-outbreaks.html
# Zulay Balza, right, recovering from Guillain-Barre syndrome in February at a hospital in Colombia. Ms. Balza did not show symptoms of the Zika virus; only one in five infected people do.
# https://www.nytimes.com/2014/12/08/health/ebola-doctor-ian-crozier-return-from-the-edge-of-death-.html
#
# Dr. Ian Crozier with children he helped save in Sierra Leone.
#
# https://www.nytimes.com/2017/05/15/health/immune-system-drugs-monoclonal-antibodies.html
# Becka Boscarino, and her son, Magglio at home. Magglio has Pompe disease, which causes a buildup of glycogen in the body. Untreated, it usually kills within the first year.
# https://www.nytimes.com/2018/01/10/health/chip-insurance-children-funding.html
# Rebecca Ribeiro with her son, Max
# https://www.nytimes.com/2012/07/24/health/antiretroviral-drug-resistance-growing-for-africa-aids-cases.html
#
# Mpumelele, 18-months-old, receives antiretroviral treatment from his cousin, as his grandmother holds his hand.
#
#
# https://www.nytimes.com/2015/05/16/health/debating-whether-preemies-are-worth-fighting-for.html
# Micah Pickering, 2, and his mother, Danielle near their home in Newton, Iowa. Micah was born at 22 weeks.
# https://www.nytimes.com/2016/11/01/health/colombia-zika-microcephaly.html
# Zuleima at home with her baby, Milagros, who was born with microcephaly, and one of her older daughters.
# https://www.nytimes.com/2017/05/08/health/artificial-wombs-ethics.html
# A premature baby resting in a N.I.C.U. in Tacoma, Wash.
# https://www.nytimes.com/2017/05/15/health/immune-system-drugs-monoclonal-antibodies.html
# Magglio Boscarino, who has the genetic disorder Pompe disease, with his mother Becka at home, above, and at school.
# https://www.nytimes.com/2017/06/19/health/guns-children-cdc-us-firearms.html
# Parents of children killed by guns held a protest in Atlanta near the National Rifle Association’s annual convention in April.
# https://www.nytimes.com/2016/02/02/health/dreams-dying-deathbed-interpretation-delirium.html
# Dr. Kerr holds the hand of a patient, Rebecca Nowak. He says that sometimes when dying people are sedated, “we are sterilizing them from their own dying process.”
# https://www.nytimes.com/2016/06/11/health/gang-stalking-targeted-individuals.html
# Officers standing over the body of Myron May on Nov. 20, 2014, after the shooting at Florida State University.
# https://www.nytimes.com/2017/05/13/health/candidate-who-director-general-ethiopia-cholera-outbreaks.html
# A woman with her baby, who was severely malnourished and had diarrhea, in 2011 in Ethiopia. Ethiopia suffered extensive outbreaks of diarrheal disease in 2006, 2009 and 2011.
# https://www.nytimes.com/2017/12/04/health/opioids-africa-pain.html
# John Kanakura, left, resting at the Cancer Charity Foundation in Kampala, Uganda. He has colon cancer that has spread to his liver. The pain, he said, “is like someone is cutting me with a knife,” but his morphine dose lets him get some sleep.

# %%
# Sports--Arousal
category_mask = np.flatnonzero(np.core.defchararray.find(details[:,3], "/sports/")!=-1)
ordered = np.argsort(predictions[category_mask][:,1])
#details[mask][ordered]
for i in range(-1, -21, -1):
    article_id = details[category_mask][:,1][ordered[i]]
    image_id = details[category_mask][:,2][ordered[i]]
    print(details[category_mask][:,3][ordered[i]])
    print(retrieve_caption(article_id, image_id))
# Out:
# https://www.nytimes.com/2012/02/28/sports/autoracing/daytona-500-delayed-by-fiery-collision.html
#
# Workers trying to extinguish a fire from a racetrack jet dryer after it was hit by a car during the Daytona 500.
#
#
# https://www.nytimes.com/2012/02/28/sports/daytona-500.html
#
# Workers trying to extinguish a fire from a racetrack jet dryer after it was hit by a car during the Daytona 500.
#
#
# https://www.nytimes.com/2017/05/22/sports/hockey/from-hockey-101-in-nashville-to-a-phd-with-predators.html
#
# Predators fans taking turns smashing an Anaheim Ducks-themed car outside Bridgestone Arena in Nashville. The Predators will take on the Ducks in Game 6 of the Western Conference finals on Monday night.
#
#
# https://www.nytimes.com/2015/06/12/sports/autoracing/on-auto-racings-deadliest-day.html
# Spectators fleeing the flames after Pierre Levegh’s Mercedes crashed during the Le Mans race on June 11, 1955, killing 83 people and Levegh.
# https://www.nytimes.com/2015/11/03/sports/soccer/russian-soccer-denies-racism-problem-even-as-it-vows-to-solve-it.html
# Fans of Spartak Moscow burned flares and displayed a swastika flag during a match in Yaroslavl, Russia.
# https://www.nytimes.com/2014/08/05/sports/autoracing/nascars-pockets-seem-deep-enough-for-action-on-concussions.html
# Geoff Bodine, in a crash at Daytona in 2000, retired two years ago and is not sure how many times he was knocked out in races.
# https://www.nytimes.com/2014/04/13/sports/soccer/25-years-after-stadium-disaster-liverpool-still-mourns.html
# The scene on the field at Hillsborough Stadium in Sheffield, England, on April 15, 1989.
# https://www.nytimes.com/2011/06/16/sports/vancouver-fans-take-to-the-streets-after-loss.html
#
# Fans of the Vancouver Canucks watched an overturned pickup truck burn during riots in downtown Vancouver, British Columbia, after Game 7.
#
#
# https://www.nytimes.com/2017/05/29/sports/mets-baseball-dwight-gooden-ceremony-bill-de-blasio.html
# Ticker tape and paper littered a street in Lower Manhattan during a parade for the New York Mets in 1986.
# https://www.nytimes.com/2016/06/25/sports/olympics/as-the-olympics-near-brazil-and-rio-let-the-bad-times-roll.html
# Supporters of Brazil’s suspended president, Dilma Rousseff, protesting at a June rally in Rio de Janeiro against Michel Temer, the interim president. Political tensions are rising in the lead-up to the Summer Games.
# https://www.nytimes.com/2012/06/16/sports/soccer/russian-hooliganism-looms-over-euro-2012.html
#
# The Polish police detaining a soccer fan during a clash between Polish and Russian fans Tuesday in Warsaw.
#
#
# https://www.nytimes.com/2010/04/05/sports/ncaabasketball/05uconn.html
#
# Baylor guard Melissa Jones tumbling after she was fouled by Caroline Doty. The Huskies ran their winning streak to 77 games.
#
#
# https://www.nytimes.com/2016/01/31/sports/why-sports-fans-risk-life-and-limb-for-a-rolled-up-t-shirt.html
# The San Antonio Spurs Coyote firing T-shirts into a crowd in a playoff game in 2014.
# https://www.nytimes.com/2016/11/02/sports/soccer/real-madrid-preparing-for-closed-door-match-at-legia-warsaw.html
# Legia Warsaw fans clashed with the police last month before the team visited Real Madrid. No fans will be present Wednesday when the teams meet again in Warsaw.
# https://www.nytimes.com/2012/01/28/sports/football/early-patriots-were-a-comical-traveling-sideshow.html
#
# When the Patriots played at Boston College in 1970, a fire broke out in the stands.
#
#
# https://www.nytimes.com/2011/09/06/sports/tennis/us-open-the-place-to-be-seen-and-heard.html
#
# Last year, three fans were ejected after they fought in the stands during a match.
#
#
# https://www.nytimes.com/2011/01/31/sports/31boxing.html
#
# Devon Alexander and Timothy Bradley fight during the WBC/WBO World Championship Unification boxing match.
#
#
# https://www.nytimes.com/2016/09/28/sports/cricket/bangladesh-pakistan-afghanistan-international-safety.html
# Pakistan has not played a Test match at home since March 2009, when the Sri Lankan team bus was attacked en route to a match in Lahore.
# https://www.nytimes.com/2012/02/29/sports/autoracing/for-nascar-a-fireball-in-the-nhl-a-trading-day-flameout.html
#
# Astoundingly, no one was hurt when Juan Pablo Montoya lost control of his car and it slammed into the track dryer during Monday's much-delayed Daytona 500.
#
#
# https://www.nytimes.com/2013/02/24/sports/last-lap-crash-in-nationwide-race-appears-to-injure-fans.html
#
# Kyle Larson, No. 32, was thrown into the fence after a crash with Brad Keselowski, driver of the No. 22 car, at Daytona International Speedway on Saturday.

# %% [markdown]
# ## Statistical Testing of Categories

# %%
np.random.seed(15654)
col_names = ["valence_mean", "arousal_mean", 
             "moral_mean", "authority_mean",
             "fairness_mean", "harm_mean",
             "ingroup_mean", "purity_mean"]

mask = mask_1
arr = []
for i in range(2,8):
    df = predictions[mask][:,i]
    arr.append(np.array([np.mean(np.random.choice(df, 100, replace = True)) for _ in range(10000)]))
arr=np.stack(arr)
spo_arr = arr

mask = mask_2
arr = []
for i in range(2,8):
    df = predictions[mask][:,i]
    arr.append(np.array([np.mean(np.random.choice(df, 100, replace = True)) for _ in range(10000)]))
arr=np.stack(arr)
bus_arr = arr

mask = mask_3
arr = []
for i in range(2,8):
    df = predictions[mask][:,i]
    arr.append(np.array([np.mean(np.random.choice(df, 100, replace = True)) for _ in range(10000)]))
arr=np.stack(arr)
tec_arr = arr

mask = mask_4
arr = []
for i in range(2,8):
    df = predictions[mask][:,i]
    arr.append(np.array([np.mean(np.random.choice(df, 100, replace = True)) for _ in range(10000)]))
arr=np.stack(arr)
sci_arr = arr

mask = mask_5
arr = []
for i in range(2,8):
    df = predictions[mask][:,i]
    arr.append(np.array([np.mean(np.random.choice(df, 100, replace = True)) for _ in range(10000)]))
arr=np.stack(arr)
hea_arr = arr

# %%
# Health highest Morality rating
variable_index = 0
highest_arr = hea_arr
other_arrs = [spo_arr, bus_arr, tec_arr, sci_arr]

cum_arr = True
for arr in other_arrs:
    cum_arr=np.logical_and(cum_arr, (highest_arr[variable_index,:])>(arr[variable_index,:]))
print(1-np.sum(cum_arr)/10000)

# %%
# Sports highest Authority rating
variable_index = 1
highest_arr = spo_arr
# [spo_arr, bus_arr, tec_arr, sci_arr, hea_arr]
other_arrs = [bus_arr, tec_arr, sci_arr, hea_arr]

cum_arr = True
for arr in other_arrs:
    cum_arr=np.logical_and(cum_arr, (highest_arr[variable_index,:])>(arr[variable_index,:]))
print(1-np.sum(cum_arr)/10000)

# %%
# Sports highest Fairness rating
variable_index = 2
highest_arr = spo_arr
# [spo_arr, bus_arr, tec_arr, sci_arr, hea_arr]
other_arrs = [bus_arr, tec_arr, sci_arr, hea_arr]

cum_arr = True
for arr in other_arrs:
    cum_arr=np.logical_and(cum_arr, (highest_arr[variable_index,:])>(arr[variable_index,:]))
print(1-np.sum(cum_arr)/10000)

# %%
# Health highest Care rating
variable_index = 3
highest_arr = hea_arr
# [spo_arr, bus_arr, tec_arr, sci_arr, hea_arr]
other_arrs = [spo_arr, bus_arr, tec_arr, sci_arr]

cum_arr = True
for arr in other_arrs:
    cum_arr=np.logical_and(cum_arr, (highest_arr[variable_index,:])>(arr[variable_index,:]))
print(1-np.sum(cum_arr)/10000)

# %%
# Sports highest Ingroup rating
variable_index = 4
highest_arr = spo_arr
# [spo_arr, bus_arr, tec_arr, sci_arr, hea_arr]
other_arrs = [bus_arr, tec_arr, sci_arr, hea_arr]

cum_arr = True
for arr in other_arrs:
    cum_arr=np.logical_and(cum_arr, (highest_arr[variable_index,:])>(arr[variable_index,:]))
print(1-np.sum(cum_arr)/10000)

# %%
# Health highest Purity rating
variable_index = 5
highest_arr = hea_arr
# [spo_arr, bus_arr, tec_arr, sci_arr, hea_arr]
other_arrs = [spo_arr, bus_arr, tec_arr, sci_arr]

cum_arr = True
for arr in other_arrs:
    cum_arr=np.logical_and(cum_arr, (highest_arr[variable_index,:])>(arr[variable_index,:]))
print(1-np.sum(cum_arr)/10000)
